# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
medi=pd.read_csv('medical_cost_insurance.csv')

# %%
medi # because i executed this again it is not showing the resampled data with encoded region column
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
medi.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
medi.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
medi['charges'].max()
# Out:
# 63770.42801

# %%
medi['charges'].median()
# Out:
# 9382.033

# %%
# the med Dataset is from line number 19
med[med['charges']<35000].describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1205.000000  1205.000000  1205.000000  1205.000000  1205.000000
# mean     38.910373     0.491286    30.109203     1.079668     0.119502
# std      14.081405     0.500132     5.999856     1.213282     0.324513
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      26.000000     0.000000    25.800000     0.000000     0.000000
# 50%      39.000000     0.000000    29.800000     1.000000     0.000000
# 75%      51.000000     1.000000    33.820000     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges  region_northwest  region_southeast  region_southwest  \
# count   1205.000000       1205.000000       1205.000000       1205.000000
# mean   10051.385831          0.253112          0.256432          0.243983
# std     7431.695100          0.434975          0.436844          0.429661
# ...

# %%
med[med['charges']>35000].describe()
# Out:
#               age         sex         bmi    children      smoker  \
# count  133.000000  133.000000  133.000000  133.000000  133.000000
# mean    41.894737    0.631579   35.684474    1.233083    0.977444
# std     13.518373    0.484200    4.484903    1.127395    0.149046
# min     18.000000    0.000000   22.895000    0.000000    0.000000
# 25%     31.000000    0.000000   32.775000    0.000000    1.000000
# 50%     43.000000    1.000000   35.300000    1.000000    1.000000
# 75%     53.000000    1.000000   37.800000    2.000000    1.000000
# max     64.000000    1.000000   52.580000    4.000000    1.000000
#
#             charges  region_northwest  region_southeast  region_southwest
# count    133.000000        133.000000        133.000000        133.000000
# mean   42435.376422          0.150376          0.413534          0.233083
# std     5478.380230          0.358791          0.494329          0.424393
# min    35069.374520          0.000000          0.000000          0.000000
# ...

# %%
med[med['smoker']==1].describe()
# Out:
#               age         sex         bmi    children  smoker       charges  \
# count  274.000000  274.000000  274.000000  274.000000   274.0    274.000000
# mean    38.514599    0.580292   30.708449    1.113139     1.0  32050.231832
# std     13.923186    0.494414    6.318644    1.157066     0.0  11541.547176
# min     18.000000    0.000000   17.195000    0.000000     1.0  12829.455100
# 25%     27.000000    0.000000   26.083750    0.000000     1.0  20826.244213
# 50%     38.000000    1.000000   30.447500    1.000000     1.0  34456.348450
# 75%     49.000000    1.000000   35.200000    2.000000     1.0  41019.207275
# max     64.000000    1.000000   52.580000    5.000000     1.0  63770.428010
#
#        region_northwest  region_southeast  region_southwest
# count        274.000000        274.000000        274.000000
# mean           0.211679          0.332117          0.211679
# std            0.409246          0.471834          0.409246
# ...

# %% [markdown]
# If we check the mean for charges > 35000(outliers according to bocx plot) and for charges<35000 we can see a vast difference in the mean of smokers which is around 0.12 for charges <35000 but
# drastically increases to 0.98 for charges>35000 suggesting that the outliers are majorly due to smokers.Smoker attract higher charges

# %%
med[med['charges']==1121.8739]
# Out:
#      age  sex    bmi  children  smoker    charges  region_northwest  \
# 940   18    1  23.21         0       0  1121.8739                 0
#
#      region_southeast  region_southwest
# 940                 1                 0

# %%
med[med['charges']==63770.42801]
# Out:
#      age  sex    bmi  children  smoker      charges  region_northwest  \
# 543   54    0  47.41         0       1  63770.42801                 0
#
#      region_southeast  region_southwest
# 543                 1                 0

# %%
med[(med['smoker']==1) & (med['charges']>35000)].describe()
# Out:
#               age         sex         bmi    children  smoker       charges  \
# count  130.000000  130.000000  130.000000  130.000000   130.0    130.000000
# mean    41.515385    0.646154   35.777731    1.207692     1.0  42578.877225
# std     13.432135    0.480012    4.462336    1.111575     0.0   5456.848646
# min     18.000000    0.000000   22.895000    0.000000     1.0  35069.374520
# 25%     31.000000    0.000000   32.776250    0.000000     1.0  38561.015225
# 50%     43.000000    1.000000   35.515000    1.000000     1.0  41797.589050
# 75%     52.000000    1.000000   37.995000    2.000000     1.0  46126.272625
# max     64.000000    1.000000   52.580000    4.000000     1.0  63770.428010
#
#        region_northwest  region_southeast  region_southwest
# count        130.000000        130.000000        130.000000
# mean           0.153846          0.415385          0.223077
# std            0.362197          0.494695          0.417920
# ...

# %%
med[(med['smoker']==1) & (med['charges']<35000)].describe()
# Out:
#               age         sex         bmi    children  smoker       charges  \
# count  144.000000  144.000000  144.000000  144.000000   144.0    144.000000
# mean    35.805556    0.520833   26.132014    1.027778     1.0  22545.204740
# std     13.847460    0.501309    3.715682    1.194067     0.0   5974.170024
# min     18.000000    0.000000   17.195000    0.000000     1.0  12829.455100
# 25%     23.750000    0.000000   23.733750    0.000000     1.0  18011.002425
# 50%     33.500000    1.000000   26.647500    1.000000     1.0  21147.186025
# 75%     47.000000    1.000000   28.407500    2.000000     1.0  25456.417363
# max     64.000000    1.000000   34.900000    5.000000     1.0  34838.873000
#
#        region_northwest  region_southeast  region_southwest
# count        144.000000        144.000000        144.000000
# mean           0.263889          0.256944          0.201389
# std            0.442278          0.438474          0.402438
# ...

# %%
med[(med['smoker']==0) & (med['charges']<35000)].describe()
# Out:
#                age          sex          bmi     children  smoker  \
# count  1061.000000  1061.000000  1061.000000  1061.000000  1061.0
# mean     39.331762     0.487276    30.648992     1.086711     0.0
# std      14.066527     0.500074     6.048599     1.216251     0.0
# min      18.000000     0.000000    15.960000     0.000000     0.0
# 25%      26.000000     0.000000    26.315000     0.000000     0.0
# 50%      40.000000     0.000000    30.305000     1.000000     0.0
# 75%      52.000000     1.000000    34.430000     2.000000     0.0
# max      64.000000     1.000000    53.130000     5.000000     0.0
#
#             charges  region_northwest  region_southeast  region_southwest
# count   1061.000000       1061.000000       1061.000000       1061.000000
# mean    8355.712011          0.251649          0.256362          0.249764
# std     5816.761930          0.434165          0.436830          0.433081
# min     1121.873900          0.000000          0.000000          0.000000
# ...

# %% [markdown]
# From the above describe functions used and the box plot below, we see that there are many outliers in the
# charges column(target column). Approximately 133 outliers of which smoking
# is a common trait. 130 out of 133 outliers are smokers. This suggest that smoking is contributing majorly
# to higher insurance cost. also if we compare the mean of charges for smokers v/s non smokers there is a vast
# difference. Mean of charges for smokers is 32050 whereas that for non smokers is 8434.
# On the other hand the mean for bmi and age in smokers and non smokers is almost equal suggesting and confirming
# that smoking is the major factor for increase in insurance costs. Now since we know this, we can say that the
# outliers hold very important information. Also out of the 274 smokers in the dataset around 130 are outliers
# and removing them will cause instability in the predictions.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(y=med['charges'])
plt.title('Box plot of Charges')
plt.show()

# %%
med.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
med.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
med.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.histplot(med['charges'], bins=30, kde=True)
plt.title('Distribution of Charges')
plt.show()

# %%
medcol=list(med.columns)

# %%
medcol
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
#Checking countplots for each column
for i in med.columns:
    print(med[i].value_counts())
    plt.figure(figsize=(10, 6))
    sns.countplot(x=i, data=med)
    plt.title(f'Count plot for {i}')
    plt.show()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
# male      676
# female    662
# Name: sex, dtype: int64
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
# no     1064
# yes     274
# Name: smoker, dtype: int64
# southeast    364
# southwest    325
# ...

# %%
# Countplot for each column
plt.figure(figsize=(12, 8))

for i, col in enumerate(med.columns):
    plt.subplot(3, 4, i + 1)
    sns.histplot(med[col],kde=True)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
#using label encoder on categorical columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
med['sex']=le.fit_transform(med['sex'])
med['smoker']=le.fit_transform(med['smoker'])
# using OneHot encoding on the region column
med = pd.get_dummies(med, columns=['region'], drop_first=True)

# %%
med
# Out:
#       age  sex     bmi  children  smoker      charges  region_northwest  \
# 0      19    0  27.900         0       1  16884.92400                 0
# 1      18    1  33.770         1       0   1725.55230                 0
# 2      28    1  33.000         3       0   4449.46200                 0
# 3      33    1  22.705         0       0  21984.47061                 1
# 4      32    1  28.880         0       0   3866.85520                 1
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    1  30.970         3       0  10600.54830                 1
# 1334   18    0  31.920         0       0   2205.98080                 0
# 1335   18    0  36.850         0       0   1629.83350                 0
# 1336   21    0  25.800         0       0   2007.94500                 0
# 1337   61    0  29.070         0       1  29141.36030                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# ...

# %%
# Looking for outliers using box plot
for i in med.columns:
    sns.boxplot(y=i, data=med)
    plt.title('Box Plot of columns')
    plt.ylabel(i)
    plt.show()

# %%
medcorr=med.corr()

# %%
medcorr
# Out:
#                        age       sex       bmi  children    smoker   charges  \
# age               1.000000 -0.020856  0.109272  0.042469 -0.025019  0.299008
# sex              -0.020856  1.000000  0.046371  0.017163  0.076185  0.057292
# bmi               0.109272  0.046371  1.000000  0.012759  0.003750  0.198341
# children          0.042469  0.017163  0.012759  1.000000  0.007673  0.067998
# smoker           -0.025019  0.076185  0.003750  0.007673  1.000000  0.787251
# charges           0.299008  0.057292  0.198341  0.067998  0.787251  1.000000
# region_northwest -0.000407 -0.011156 -0.135996  0.024806 -0.036945 -0.039905
# region_southeast -0.011642  0.017117  0.270025 -0.023066  0.068498  0.073982
# region_southwest  0.010016 -0.004184 -0.006205  0.021914 -0.036945 -0.043210
#
#                   region_northwest  region_southeast  region_southwest
# age                      -0.000407         -0.011642          0.010016
# ...

# %%
plt.figure(figsize=(10, 4))
sns.heatmap(medcorr,annot=True,cmap='coolwarm')
# here we can see that the smoker and charges column are have high positive collinearity
# Out:
# <Axes: >

# %%
# Applying log transformation
med['log_charges'] = np.log(med['charges'])

# histplot
plt.figure(figsize=(10, 6))
sns.histplot(med['log_charges'], kde=True)
plt.title('Log Transformed Charges Distribution')
plt.show()

# %%
med 
# However after using the log tranformed data the model was giving much lower r2 score 
#so going ahead with the regular data
# Out:
#       age  sex     bmi  children  smoker      charges  region_northwest  \
# 0      19    0  27.900         0       1  16884.92400                 0
# 1      18    1  33.770         1       0   1725.55230                 0
# 2      28    1  33.000         3       0   4449.46200                 0
# 3      33    1  22.705         0       0  21984.47061                 1
# 4      32    1  28.880         0       0   3866.85520                 1
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    1  30.970         3       0  10600.54830                 1
# 1334   18    0  31.920         0       0   2205.98080                 0
# 1335   18    0  36.850         0       0   1629.83350                 0
# 1336   21    0  25.800         0       0   2007.94500                 0
# 1337   61    0  29.070         0       1  29141.36030                 1
#
#       region_southeast  region_southwest  log_charges
# ...

# %%
med_x=med.drop(columns=['charges','log_charges'],axis=1)

# %%
med_y=med['charges']

# %%
med_x
# Out:
#       age  sex     bmi  children  smoker  region_northwest  region_southeast  \
# 0      19    0  27.900         0       1                 0                 0
# 1      18    1  33.770         1       0                 0                 1
# 2      28    1  33.000         3       0                 0                 1
# 3      33    1  22.705         0       0                 1                 0
# 4      32    1  28.880         0       0                 1                 0
# ...   ...  ...     ...       ...     ...               ...               ...
# 1333   50    1  30.970         3       0                 1                 0
# 1334   18    0  31.920         0       0                 0                 0
# 1335   18    0  36.850         0       0                 0                 1
# 1336   21    0  25.800         0       0                 0                 0
# 1337   61    0  29.070         0       1                 1                 0
#
#       region_southwest
# ...

# %%
sns.countplot(x=med['smoker'],data=med)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
med_y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(med_x)

# %%
x_scaled
# Out:
# array([[-1.43876426, -1.0105187 , -0.45332   , ..., -0.56641788,
#         -0.61132367,  1.76548098],
#        [-1.50996545,  0.98959079,  0.5096211 , ..., -0.56641788,
#          1.63579466, -0.56641788],
#        [-0.79795355,  0.98959079,  0.38330685, ..., -0.56641788,
#          1.63579466, -0.56641788],
#        ...,
#        [-1.50996545, -1.0105187 ,  1.0148781 , ..., -0.56641788,
#          1.63579466, -0.56641788],
#        [-1.29636188, -1.0105187 , -0.79781341, ..., -0.56641788,
#         -0.61132367,  1.76548098],
#        [ 1.55168573, -1.0105187 , -0.26138796, ...,  1.76548098,
#         -0.61132367, -0.56641788]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,med_y,test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

gbr = GradientBoostingRegressor()

# hyperparameters tuning inputs
gbrparams = {
    'n_estimators': [50, 100, 250],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'subsample': [0.5, 0.7, 0.8, 0.9],
    'max_features': ['sqrt', 'log2']
}

# Use GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(estimator=gbr, param_grid=gbrparams, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)

# Get the best model
best_gbr = grid_search.best_estimator_

# Print the best parameters
print("Best parameters found: ", grid_search.best_params_)
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50, 'subsample': 0.7}

# %%
boost=GradientBoostingRegressor(learning_rate=0.1, max_depth= 4, max_features= 'log2', min_samples_leaf= 5, min_samples_split= 5, n_estimators= 50, subsample= 0.7)
boost.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=4, max_features='log2', min_samples_leaf=5,
#                           min_samples_split=5, n_estimators=50, subsample=0.7)

# %%
b_pred=boost.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

maeb = mean_absolute_error(y_test, b_pred)
mseb = mean_squared_error(y_test, b_pred)
rmseb = np.sqrt(mseb)
r2b = r2_score(y_test, b_pred)

print(f"Mean Absolute Error (MAE): {maeb}")
print(f"Mean Squared Error (MSE): {mseb}")
print(f"Root Mean Squared Error (RMSE): {rmseb}")
print(f"R-squared (R²) Score: {r2b}")
# Out:
# Mean Absolute Error (MAE): 2482.1482723793456
# Mean Squared Error (MSE): 17804730.527508378
# Root Mean Squared Error (RMSE): 4219.565205978974
# R-squared (R²) Score: 0.8853148083309663

# %%
#trying linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lrpred=lr.predict(x_test)

# %%
maelr = mean_absolute_error(y_test, lrpred)
mselr = mean_squared_error(y_test, lrpred)
rmselr = np.sqrt(mselr)
r2lr = r2_score(y_test, lrpred)

print(f"Mean Absolute Error (MAE): {maelr}")
print(f"Mean Squared Error (MSE): {mselr}")
print(f"Root Mean Squared Error (RMSE): {rmselr}")
print(f"R-squared (R²) Score: {r2lr}")
# Out:
# Mean Absolute Error (MAE): 4181.194473753652
# Mean Squared Error (MSE): 33596915.85136147
# Root Mean Squared Error (RMSE): 5796.2846592762735
# R-squared (R²) Score: 0.7835929767120723

# %%
#trying lasso regression model
from sklearn.linear_model import Lasso
las=Lasso(alpha=0.001)

# %%
las.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.001)

# %%
laspred=las.predict(x_test)

# %%
maelas = mean_absolute_error(y_test, laspred)
mselas = mean_squared_error(y_test, laspred)
rmselas = np.sqrt(mselas)
r2las = r2_score(y_test, laspred)

print(f"Mean Absolute Error (MAE): {maelas}")
print(f"Mean Squared Error (MSE): {mselas}")
print(f"Root Mean Squared Error (RMSE): {rmselas}")
print(f"R-squared (R²) Score: {r2las}")
# Out:
# Mean Absolute Error (MAE): 4181.194787523272
# Mean Squared Error (MSE): 33596920.073228166
# Root Mean Squared Error (RMSE): 5796.285023463577
# R-squared (R²) Score: 0.7835929495178616

# %%
#passing new data
new=[[50,1,30.970,3,0,1,0,0]]

# %%
#Scaling the new data
new_scaler=StandardScaler()
scaled_new=new_scaler.fit_transform(new)

# %%
boost.predict(scaled_new)
# Out:
# array([8041.71470104])

# %% [markdown]
# ## The best R2 score of 88.53% is given by GradientBoostingRegressor
